# %%
Q.1. What are keywords in python? Using the keyword library, print all the python keywords.

Python
import keyword
print(keyword.kwlist)

Output:

['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

Q.2. What are the rules to create variables in python?

Variable names can only contain letters, numbers, and underscores.
Variable names cannot start with a number.
Variable names cannot be keywords.
Q.3. What are the standards and conventions followed for the nomenclature of variables in
python to improve code readability and maintainability?

Variable names should be descriptive and meaningful.
Variable names should be in lowercase and separated by underscores.
Global variables should be prefixed with a double underscore (e.g. __global_variable).
Q.4. What will happen if a keyword is used as a variable name?
If a keyword is used as a variable name, it will cause a syntax error.

Q.5. For what purpose def keyword is used?
The def keyword is used to define functions.

Q.6. What is the operation of this special character ‘\’?
The backslash (\) character is used to escape special characters. For example, the string "hello\nworld" will print the following output:

hello
world
Q.7. Give an example of the following conditions:
(i) Homogeneous list
(ii) Heterogeneous set
(iii) Homogeneous tuple

Homogeneous list: [1, 2, 3, 4, 5]
Heterogeneous set: {1, 2.0, "hello", True}
Homogeneous tuple: (1, 2, 3, 4, 5)
Q.8. Explain the mutable and immutable data types with proper explanation & examples.

Mutable data types can be changed after they are created. Examples of mutable data types include lists, dictionaries, and sets.
Immutable data types cannot be changed after they are created. Examples of immutable data types include strings, tuples, and numbers.
Q.9. Write a code to create the given structure using only for loop.

Python
for i in range(1, 9):
  print("*" * i)

Output:

*
***
*****
*******
*********
Q.10. Write a code to create the given structure using while loop.

Python
i = 5
while i >= 1:
  print("|*" * i)
  i -= 1

Output:

|||||||||
|||||||
|||||
|||
|
