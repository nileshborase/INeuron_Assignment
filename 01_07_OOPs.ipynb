# %%
1. What is the primary goal of Object-Oriented Programming (OOP)?
The primary goal of object-oriented programming (OOP) is to simplify the development and maintenance of large software programs by providing a way to group data and functionality together.
2. What is an object in Python?
An object in Python is a real-world entity or concept that has been modeled in code. It has data and methods associated with it. For example, a car object might have data members like name, color, and make, and methods like drive() and brake().
3. What is a class in Python?
A class in Python is a blueprint for creating objects. It defines the data and methods that all objects of that class will have. For example, the Car class might define the data members and methods mentioned above.
4. What are attributes and methods in a class?
Attributes and methods are the two main components of a class. Attributes are variables that are associated with an object, while methods are functions that are associated with an object.
5. What is the difference between class variables and instance variables in Python?
The difference between class variables and instance variables is that class variables are shared by all instances of a class, while instance variables are unique to each instance. For example, the Car class might have a class variable called MAX_SPEED that is shared by all car objects. Each car object would also have its own instance variable called current_speed.
6. What is the purpose of the self parameter in Python class methods?
The self parameter in Python class methods refers to the current object. It is used to access the object's attributes and methods.

# %%
Question No. 7
Answer-


class Book:
    def __init__(self, title, author, isbn, publication_year, available_copies):
        self.title = title
        self.author = author
        self.isbn = isbn
        self.publication_year = publication_year
        self.available_copies = available_copies

    def check_out(self):
        if self.available_copies > 0:
            self.available_copies -= 1
        else:
            print("Sorry, this book is not available.")

    def return_book(self):
        self.available_copies += 1

    def display_book_info(self):
        print("Title:", self.title)
        print("Author:", self.author)
        print("ISBN:", self.isbn)
        print("Publication year:", self.publication_year)
        print("Available copies:", self.available_copies)

# %%
Question No. 8
Answer-

class Ticket:
    def __init__(self, ticket_id, event_name, event_date, venue, seat_number, price, is_reserved):
        self.ticket_id = ticket_id
        self.event_name = event_name
        self.event_date = event_date
        self.venue = venue
        self.seat_number = seat_number
        self.price = price
        self.is_reserved = is_reserved

    def reserve_ticket(self):
        if self.is_reserved:
            print("Ticket is already reserved.")
        else:
            self.is_reserved = True

    def cancel_reservation(self):
        if not self.is_reserved:
            print("Ticket is not reserved.")
        else:
            self.is_reserved = False

    def display_ticket_info(self):
        print("Ticket ID:", self.ticket_id)
        print("Event name:", self.event_name)
        print("Event date:", self.event_date)
        print("Venue:", self.venue)
        print("Seat number:", self.seat_number)
        print("Price:", self.price)
        print("Reservation status:", self.is_reserved)

# %%
Question No. 9
Answer-

class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)

    def remove_item(self, item):
        self.items.remove(item)

    def view_cart(self):
        print("Items in the shopping cart:")
        for item in self.items:
            print(item)

    def clear_cart(self):
        self.items = []

# %%
Question No. 10
Answer-


class Student:
    def __init__(self, name, age, grade, student_id, attendance):
        self.name = name
        self.age = age
        self.grade = grade
        self.student_id = student_id
        self.attendance = attendance

    def update_attendance(self, date, status):
        self.attendance[date] = status

    def get_attendance(self):
        return self.attendance

    def get_average_attendance(self):
        total_days = len(self.attendance)
        present_days = 0
        for date, status in self.attendance.items():
            if status == "present":
                present_days += 1
        return (present_days / total_days) * 100
